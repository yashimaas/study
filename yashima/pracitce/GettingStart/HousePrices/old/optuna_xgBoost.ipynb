# %%
! pip install optuna

# %%
import numpy as np
import sklearn.metrics
from xgboost import XGBRegressor
import optuna
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_log_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

# %%
'''
データのロード
'''
import pickle

pickle_file = "./droped_HousePrice_data_kernel.pickle"
with open(pickle_file, 'rb') as f:
    X_train = pickle.load(f)
    Y_train = pickle.load(f)
    X_test = pickle.load(f)
#     train = pickle.load(f)
#     test = pickle.load(f)
#     Id = pickle.load(f)

# %%
# (X_train, X_val, Y_train, Y_val) = train_test_split(X_train, Y_train, test_size=0.2, random_state=666)

# %%
'''
ハイパーパラメータの最適化
'''
def objective(trial):
    # hypyer param
    max_depth = trial.suggest_int('max_depth', 3, 7) 
    n_estimators = trial.suggest_int('n_estimators', 1800, 3500) 
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'auto', 'log2'])
    learning_rate = trial.suggest_uniform('learning_rate', 0.005, 0.06)
    min_child_weight = trial.suggest_int('min_child_weight', 1, 5)
    colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.1, 1)
    subsample= trial.suggest_uniform('subsample', 0.1, 1)
    eta = trial.suggest_uniform('eta', 0.1, 0.9)
 
    # callback
    pruning_callback = optuna.integration.XGBoostPruningCallback(trial, 'validation-error')
 
    # model
    model = XGBRegressor(
        max_depth=max_depth,
        n_estimators=n_estimators,
        max_features=max_features,
        learning_rate= learning_rate,
        min_child_weight= min_child_weight, 
        colsample_bytree = colsample_bytree, 
        subsample = subsample, 
        eta = eta, 
        n_jobs=-1,
        random_state = 1,
#         callback=[pruning_callback]   # cross_validationをするときは除外
    )
    

    kf = KFold(5, shuffle=True, random_state=1).get_n_splits(X_train)
    rmse = np.sqrt(-cross_val_score(model, X_train,Y_train, scoring="neg_mean_squared_error", cv=kf, verbose=0))
    
    return rmse.mean()

# %%
#     # fit
#     model.fit(X_train, 
#               Y_train, 
#               eval_metric="rmse", 
#               eval_set=[
#                   (X_train, Y_train),
#                   (X_val, Y_val)
#               ], 
#               verbose=True, 
#               early_stopping_rounds = 10)
 
#     # eval
#     score = model.evals_result()['validation_1']['rmse'][-1]
#     return score

# %%
# 学習の実行
# https://optuna.readthedocs.io/en/stable/reference/study.html#optuna.study.Study.optimize
study = optuna.create_study()
study.optimize(func=objective, # 実行する関数
               n_trials=100, # HPO試行回数
               timeout=None, # 与えられた秒数後に学習を中止します。default=None
               n_jobs=-1 # 並列実行するjob数
              )
# Out:
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:09:38,281] Finished trial#1 resulted in value: 0.12689996993408126. Current best value is 0.12689996993408126 with parameters: {'max_depth': 4, 'n_estimators': 2775, 'max_features': 'sqrt', 'learning_rate': 0.05713597666854238, 'min_child_weight': 4, 'colsample_bytree': 0.593349003844969, 'subsample': 0.5057505303815958, 'eta': 0.7221946046606826}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:09:45,731] Finished trial#0 resulted in value: 0.12227424391210792. Current best value is 0.12227424391210792 with parameters: {'max_depth': 6, 'n_estimators': 2121, 'max_features': 'log2', 'learning_rate': 0.022512537989536358, 'min_child_weight': 2, 'colsample_bytree': 0.5840400652008504, 'subsample': 0.5524576572348173, 'eta': 0.10346035576252106}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:10:06,031] Finished trial#2 resulted in value: 0.1233772265101267. Current best value is 0.12227424391210792 with parameters: {'max_depth': 6, 'n_estimators': 2121, 'max_features': 'log2', 'learning_rate': 0.022512537989536358, 'min_child_weight': 2, 'colsample_bytree': 0.5840400652008504, 'subsample': 0.5524576572348173, 'eta': 0.10346035576252106}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:10:21,364] Finished trial#3 resulted in value: 0.1237276838644068. Current best value is 0.12227424391210792 with parameters: {'max_depth': 6, 'n_estimators': 2121, 'max_features': 'log2', 'learning_rate': 0.022512537989536358, 'min_child_weight': 2, 'colsample_bytree': 0.5840400652008504, 'subsample': 0.5524576572348173, 'eta': 0.10346035576252106}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:10:56,244] Finished trial#4 resulted in value: 0.12443286938566075. Current best value is 0.12227424391210792 with parameters: {'max_depth': 6, 'n_estimators': 2121, 'max_features': 'log2', 'learning_rate': 0.022512537989536358, 'min_child_weight': 2, 'colsample_bytree': 0.5840400652008504, 'subsample': 0.5524576572348173, 'eta': 0.10346035576252106}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:11:04,288] Finished trial#5 resulted in value: 0.12447253544808785. Current best value is 0.12227424391210792 with parameters: {'max_depth': 6, 'n_estimators': 2121, 'max_features': 'log2', 'learning_rate': 0.022512537989536358, 'min_child_weight': 2, 'colsample_bytree': 0.5840400652008504, 'subsample': 0.5524576572348173, 'eta': 0.10346035576252106}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:11:41,824] Finished trial#7 resulted in value: 0.13063726183345772. Current best value is 0.12227424391210792 with parameters: {'max_depth': 6, 'n_estimators': 2121, 'max_features': 'log2', 'learning_rate': 0.022512537989536358, 'min_child_weight': 2, 'colsample_bytree': 0.5840400652008504, 'subsample': 0.5524576572348173, 'eta': 0.10346035576252106}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:12:04,606] Finished trial#6 resulted in value: 0.12616172354478858. Current best value is 0.12227424391210792 with parameters: {'max_depth': 6, 'n_estimators': 2121, 'max_features': 'log2', 'learning_rate': 0.022512537989536358, 'min_child_weight': 2, 'colsample_bytree': 0.5840400652008504, 'subsample': 0.5524576572348173, 'eta': 0.10346035576252106}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:12:29,932] Finished trial#8 resulted in value: 0.1265094404373469. Current best value is 0.12227424391210792 with parameters: {'max_depth': 6, 'n_estimators': 2121, 'max_features': 'log2', 'learning_rate': 0.022512537989536358, 'min_child_weight': 2, 'colsample_bytree': 0.5840400652008504, 'subsample': 0.5524576572348173, 'eta': 0.10346035576252106}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:13:00,750] Finished trial#9 resulted in value: 0.12573672002766406. Current best value is 0.12227424391210792 with parameters: {'max_depth': 6, 'n_estimators': 2121, 'max_features': 'log2', 'learning_rate': 0.022512537989536358, 'min_child_weight': 2, 'colsample_bytree': 0.5840400652008504, 'subsample': 0.5524576572348173, 'eta': 0.10346035576252106}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:13:41,548] Finished trial#10 resulted in value: 0.12447735925709917. Current best value is 0.12227424391210792 with parameters: {'max_depth': 6, 'n_estimators': 2121, 'max_features': 'log2', 'learning_rate': 0.022512537989536358, 'min_child_weight': 2, 'colsample_bytree': 0.5840400652008504, 'subsample': 0.5524576572348173, 'eta': 0.10346035576252106}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:13:47,861] Finished trial#11 resulted in value: 0.12297885028929008. Current best value is 0.12227424391210792 with parameters: {'max_depth': 6, 'n_estimators': 2121, 'max_features': 'log2', 'learning_rate': 0.022512537989536358, 'min_child_weight': 2, 'colsample_bytree': 0.5840400652008504, 'subsample': 0.5524576572348173, 'eta': 0.10346035576252106}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:14:28,405] Finished trial#12 resulted in value: 0.12351646056617098. Current best value is 0.12227424391210792 with parameters: {'max_depth': 6, 'n_estimators': 2121, 'max_features': 'log2', 'learning_rate': 0.022512537989536358, 'min_child_weight': 2, 'colsample_bytree': 0.5840400652008504, 'subsample': 0.5524576572348173, 'eta': 0.10346035576252106}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:14:51,857] Finished trial#13 resulted in value: 0.12317519313925156. Current best value is 0.12227424391210792 with parameters: {'max_depth': 6, 'n_estimators': 2121, 'max_features': 'log2', 'learning_rate': 0.022512537989536358, 'min_child_weight': 2, 'colsample_bytree': 0.5840400652008504, 'subsample': 0.5524576572348173, 'eta': 0.10346035576252106}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:15:40,247] Finished trial#14 resulted in value: 0.12287911876233912. Current best value is 0.12227424391210792 with parameters: {'max_depth': 6, 'n_estimators': 2121, 'max_features': 'log2', 'learning_rate': 0.022512537989536358, 'min_child_weight': 2, 'colsample_bytree': 0.5840400652008504, 'subsample': 0.5524576572348173, 'eta': 0.10346035576252106}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:16:23,964] Finished trial#15 resulted in value: 0.12431886790462872. Current best value is 0.12227424391210792 with parameters: {'max_depth': 6, 'n_estimators': 2121, 'max_features': 'log2', 'learning_rate': 0.022512537989536358, 'min_child_weight': 2, 'colsample_bytree': 0.5840400652008504, 'subsample': 0.5524576572348173, 'eta': 0.10346035576252106}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:16:30,111] Finished trial#16 resulted in value: 0.1213567182025063. Current best value is 0.1213567182025063 with parameters: {'max_depth': 4, 'n_estimators': 3453, 'max_features': 'log2', 'learning_rate': 0.008308244151654952, 'min_child_weight': 3, 'colsample_bytree': 0.3862851653591859, 'subsample': 0.32453387456118243, 'eta': 0.8340041434987042}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:17:03,615] Finished trial#17 resulted in value: 0.12247198305309567. Current best value is 0.1213567182025063 with parameters: {'max_depth': 4, 'n_estimators': 3453, 'max_features': 'log2', 'learning_rate': 0.008308244151654952, 'min_child_weight': 3, 'colsample_bytree': 0.3862851653591859, 'subsample': 0.32453387456118243, 'eta': 0.8340041434987042}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:17:17,025] Finished trial#18 resulted in value: 0.12181038280779474. Current best value is 0.1213567182025063 with parameters: {'max_depth': 4, 'n_estimators': 3453, 'max_features': 'log2', 'learning_rate': 0.008308244151654952, 'min_child_weight': 3, 'colsample_bytree': 0.3862851653591859, 'subsample': 0.32453387456118243, 'eta': 0.8340041434987042}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:17:45,086] Finished trial#19 resulted in value: 0.12022520029493795. Current best value is 0.12022520029493795 with parameters: {'max_depth': 4, 'n_estimators': 3250, 'max_features': 'log2', 'learning_rate': 0.012720960049438056, 'min_child_weight': 3, 'colsample_bytree': 0.23051950024233556, 'subsample': 0.6174962576166607, 'eta': 0.7856536253392613}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:17:48,919] Finished trial#20 resulted in value: 0.1228034109240034. Current best value is 0.12022520029493795 with parameters: {'max_depth': 4, 'n_estimators': 3250, 'max_features': 'log2', 'learning_rate': 0.012720960049438056, 'min_child_weight': 3, 'colsample_bytree': 0.23051950024233556, 'subsample': 0.6174962576166607, 'eta': 0.7856536253392613}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:18:22,790] Finished trial#21 resulted in value: 0.12031258426917375. Current best value is 0.12022520029493795 with parameters: {'max_depth': 4, 'n_estimators': 3250, 'max_features': 'log2', 'learning_rate': 0.012720960049438056, 'min_child_weight': 3, 'colsample_bytree': 0.23051950024233556, 'subsample': 0.6174962576166607, 'eta': 0.7856536253392613}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:18:26,598] Finished trial#22 resulted in value: 0.1213357547969917. Current best value is 0.12022520029493795 with parameters: {'max_depth': 4, 'n_estimators': 3250, 'max_features': 'log2', 'learning_rate': 0.012720960049438056, 'min_child_weight': 3, 'colsample_bytree': 0.23051950024233556, 'subsample': 0.6174962576166607, 'eta': 0.7856536253392613}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:18:58,951] Finished trial#23 resulted in value: 0.12252894713003584. Current best value is 0.12022520029493795 with parameters: {'max_depth': 4, 'n_estimators': 3250, 'max_features': 'log2', 'learning_rate': 0.012720960049438056, 'min_child_weight': 3, 'colsample_bytree': 0.23051950024233556, 'subsample': 0.6174962576166607, 'eta': 0.7856536253392613}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:19:05,219] Finished trial#24 resulted in value: 0.12237413922580428. Current best value is 0.12022520029493795 with parameters: {'max_depth': 4, 'n_estimators': 3250, 'max_features': 'log2', 'learning_rate': 0.012720960049438056, 'min_child_weight': 3, 'colsample_bytree': 0.23051950024233556, 'subsample': 0.6174962576166607, 'eta': 0.7856536253392613}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:19:32,963] Finished trial#25 resulted in value: 0.12162091995304787. Current best value is 0.12022520029493795 with parameters: {'max_depth': 4, 'n_estimators': 3250, 'max_features': 'log2', 'learning_rate': 0.012720960049438056, 'min_child_weight': 3, 'colsample_bytree': 0.23051950024233556, 'subsample': 0.6174962576166607, 'eta': 0.7856536253392613}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:19:41,564] Finished trial#26 resulted in value: 0.12165279685218014. Current best value is 0.12022520029493795 with parameters: {'max_depth': 4, 'n_estimators': 3250, 'max_features': 'log2', 'learning_rate': 0.012720960049438056, 'min_child_weight': 3, 'colsample_bytree': 0.23051950024233556, 'subsample': 0.6174962576166607, 'eta': 0.7856536253392613}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:20:23,899] Finished trial#27 resulted in value: 0.11979793003975892. Current best value is 0.11979793003975892 with parameters: {'max_depth': 5, 'n_estimators': 3024, 'max_features': 'auto', 'learning_rate': 0.017036971764434177, 'min_child_weight': 2, 'colsample_bytree': 0.28551349623024136, 'subsample': 0.7076922406917953, 'eta': 0.7295874641102237}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:20:26,158] Finished trial#28 resulted in value: 0.12245184963025631. Current best value is 0.11979793003975892 with parameters: {'max_depth': 5, 'n_estimators': 3024, 'max_features': 'auto', 'learning_rate': 0.017036971764434177, 'min_child_weight': 2, 'colsample_bytree': 0.28551349623024136, 'subsample': 0.7076922406917953, 'eta': 0.7295874641102237}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:21:31,527] Finished trial#29 resulted in value: 0.12174991156090671. Current best value is 0.11979793003975892 with parameters: {'max_depth': 5, 'n_estimators': 3024, 'max_features': 'auto', 'learning_rate': 0.017036971764434177, 'min_child_weight': 2, 'colsample_bytree': 0.28551349623024136, 'subsample': 0.7076922406917953, 'eta': 0.7295874641102237}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:21:32,457] Finished trial#30 resulted in value: 0.12217061239362736. Current best value is 0.11979793003975892 with parameters: {'max_depth': 5, 'n_estimators': 3024, 'max_features': 'auto', 'learning_rate': 0.017036971764434177, 'min_child_weight': 2, 'colsample_bytree': 0.28551349623024136, 'subsample': 0.7076922406917953, 'eta': 0.7295874641102237}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:22:20,614] Finished trial#31 resulted in value: 0.12131997318227747. Current best value is 0.11979793003975892 with parameters: {'max_depth': 5, 'n_estimators': 3024, 'max_features': 'auto', 'learning_rate': 0.017036971764434177, 'min_child_weight': 2, 'colsample_bytree': 0.28551349623024136, 'subsample': 0.7076922406917953, 'eta': 0.7295874641102237}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:22:25,198] Finished trial#32 resulted in value: 0.12082065701051396. Current best value is 0.11979793003975892 with parameters: {'max_depth': 5, 'n_estimators': 3024, 'max_features': 'auto', 'learning_rate': 0.017036971764434177, 'min_child_weight': 2, 'colsample_bytree': 0.28551349623024136, 'subsample': 0.7076922406917953, 'eta': 0.7295874641102237}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:23:10,504] Finished trial#34 resulted in value: 0.12361212690035109. Current best value is 0.11979793003975892 with parameters: {'max_depth': 5, 'n_estimators': 3024, 'max_features': 'auto', 'learning_rate': 0.017036971764434177, 'min_child_weight': 2, 'colsample_bytree': 0.28551349623024136, 'subsample': 0.7076922406917953, 'eta': 0.7295874641102237}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:23:31,757] Finished trial#33 resulted in value: 0.12448753546917772. Current best value is 0.11979793003975892 with parameters: {'max_depth': 5, 'n_estimators': 3024, 'max_features': 'auto', 'learning_rate': 0.017036971764434177, 'min_child_weight': 2, 'colsample_bytree': 0.28551349623024136, 'subsample': 0.7076922406917953, 'eta': 0.7295874641102237}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:23:52,904] Finished trial#35 resulted in value: 0.12133767343835541. Current best value is 0.11979793003975892 with parameters: {'max_depth': 5, 'n_estimators': 3024, 'max_features': 'auto', 'learning_rate': 0.017036971764434177, 'min_child_weight': 2, 'colsample_bytree': 0.28551349623024136, 'subsample': 0.7076922406917953, 'eta': 0.7295874641102237}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:23:58,947] Finished trial#36 resulted in value: 0.1222169087568. Current best value is 0.11979793003975892 with parameters: {'max_depth': 5, 'n_estimators': 3024, 'max_features': 'auto', 'learning_rate': 0.017036971764434177, 'min_child_weight': 2, 'colsample_bytree': 0.28551349623024136, 'subsample': 0.7076922406917953, 'eta': 0.7295874641102237}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:24:23,937] Finished trial#37 resulted in value: 0.1220620402106942. Current best value is 0.11979793003975892 with parameters: {'max_depth': 5, 'n_estimators': 3024, 'max_features': 'auto', 'learning_rate': 0.017036971764434177, 'min_child_weight': 2, 'colsample_bytree': 0.28551349623024136, 'subsample': 0.7076922406917953, 'eta': 0.7295874641102237}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:24:36,326] Finished trial#38 resulted in value: 0.12121768032852036. Current best value is 0.11979793003975892 with parameters: {'max_depth': 5, 'n_estimators': 3024, 'max_features': 'auto', 'learning_rate': 0.017036971764434177, 'min_child_weight': 2, 'colsample_bytree': 0.28551349623024136, 'subsample': 0.7076922406917953, 'eta': 0.7295874641102237}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:25:12,958] Finished trial#39 resulted in value: 0.12213463700711928. Current best value is 0.11979793003975892 with parameters: {'max_depth': 5, 'n_estimators': 3024, 'max_features': 'auto', 'learning_rate': 0.017036971764434177, 'min_child_weight': 2, 'colsample_bytree': 0.28551349623024136, 'subsample': 0.7076922406917953, 'eta': 0.7295874641102237}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:25:55,033] Finished trial#40 resulted in value: 0.12305050392068546. Current best value is 0.11979793003975892 with parameters: {'max_depth': 5, 'n_estimators': 3024, 'max_features': 'auto', 'learning_rate': 0.017036971764434177, 'min_child_weight': 2, 'colsample_bytree': 0.28551349623024136, 'subsample': 0.7076922406917953, 'eta': 0.7295874641102237}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:26:10,731] Finished trial#41 resulted in value: 0.12721934148857955. Current best value is 0.11979793003975892 with parameters: {'max_depth': 5, 'n_estimators': 3024, 'max_features': 'auto', 'learning_rate': 0.017036971764434177, 'min_child_weight': 2, 'colsample_bytree': 0.28551349623024136, 'subsample': 0.7076922406917953, 'eta': 0.7295874641102237}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:26:26,572] Finished trial#42 resulted in value: 0.12211538091948897. Current best value is 0.11979793003975892 with parameters: {'max_depth': 5, 'n_estimators': 3024, 'max_features': 'auto', 'learning_rate': 0.017036971764434177, 'min_child_weight': 2, 'colsample_bytree': 0.28551349623024136, 'subsample': 0.7076922406917953, 'eta': 0.7295874641102237}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# ...
#
# [I 2019-05-23 04:43:18,441] Finished trial#85 resulted in value: 0.1221150934671644. Current best value is 0.11905349387227551 with parameters: {'max_depth': 4, 'n_estimators': 3006, 'max_features': 'log2', 'learning_rate': 0.008058401703663098, 'min_child_weight': 3, 'colsample_bytree': 0.2323201231321826, 'subsample': 0.6423192666070391, 'eta': 0.7834739304420851}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:43:30,876] Finished trial#84 resulted in value: 0.12356030792087128. Current best value is 0.11905349387227551 with parameters: {'max_depth': 4, 'n_estimators': 3006, 'max_features': 'log2', 'learning_rate': 0.008058401703663098, 'min_child_weight': 3, 'colsample_bytree': 0.2323201231321826, 'subsample': 0.6423192666070391, 'eta': 0.7834739304420851}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:44:10,759] Finished trial#86 resulted in value: 0.12136930186583958. Current best value is 0.11905349387227551 with parameters: {'max_depth': 4, 'n_estimators': 3006, 'max_features': 'log2', 'learning_rate': 0.008058401703663098, 'min_child_weight': 3, 'colsample_bytree': 0.2323201231321826, 'subsample': 0.6423192666070391, 'eta': 0.7834739304420851}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:44:27,795] Finished trial#87 resulted in value: 0.12140359652198715. Current best value is 0.11905349387227551 with parameters: {'max_depth': 4, 'n_estimators': 3006, 'max_features': 'log2', 'learning_rate': 0.008058401703663098, 'min_child_weight': 3, 'colsample_bytree': 0.2323201231321826, 'subsample': 0.6423192666070391, 'eta': 0.7834739304420851}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:44:43,230] Finished trial#88 resulted in value: 0.1213786349073112. Current best value is 0.11905349387227551 with parameters: {'max_depth': 4, 'n_estimators': 3006, 'max_features': 'log2', 'learning_rate': 0.008058401703663098, 'min_child_weight': 3, 'colsample_bytree': 0.2323201231321826, 'subsample': 0.6423192666070391, 'eta': 0.7834739304420851}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:44:58,989] Finished trial#89 resulted in value: 0.12127365269295198. Current best value is 0.11905349387227551 with parameters: {'max_depth': 4, 'n_estimators': 3006, 'max_features': 'log2', 'learning_rate': 0.008058401703663098, 'min_child_weight': 3, 'colsample_bytree': 0.2323201231321826, 'subsample': 0.6423192666070391, 'eta': 0.7834739304420851}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:45:34,094] Finished trial#91 resulted in value: 0.12388261286198785. Current best value is 0.11905349387227551 with parameters: {'max_depth': 4, 'n_estimators': 3006, 'max_features': 'log2', 'learning_rate': 0.008058401703663098, 'min_child_weight': 3, 'colsample_bytree': 0.2323201231321826, 'subsample': 0.6423192666070391, 'eta': 0.7834739304420851}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:45:34,992] Finished trial#90 resulted in value: 0.12325300809366083. Current best value is 0.11905349387227551 with parameters: {'max_depth': 4, 'n_estimators': 3006, 'max_features': 'log2', 'learning_rate': 0.008058401703663098, 'min_child_weight': 3, 'colsample_bytree': 0.2323201231321826, 'subsample': 0.6423192666070391, 'eta': 0.7834739304420851}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:46:05,956] Finished trial#93 resulted in value: 0.12156524390269904. Current best value is 0.11905349387227551 with parameters: {'max_depth': 4, 'n_estimators': 3006, 'max_features': 'log2', 'learning_rate': 0.008058401703663098, 'min_child_weight': 3, 'colsample_bytree': 0.2323201231321826, 'subsample': 0.6423192666070391, 'eta': 0.7834739304420851}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:46:16,064] Finished trial#92 resulted in value: 0.12076510746073596. Current best value is 0.11905349387227551 with parameters: {'max_depth': 4, 'n_estimators': 3006, 'max_features': 'log2', 'learning_rate': 0.008058401703663098, 'min_child_weight': 3, 'colsample_bytree': 0.2323201231321826, 'subsample': 0.6423192666070391, 'eta': 0.7834739304420851}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:46:48,033] Finished trial#95 resulted in value: 0.12221968573815027. Current best value is 0.11905349387227551 with parameters: {'max_depth': 4, 'n_estimators': 3006, 'max_features': 'log2', 'learning_rate': 0.008058401703663098, 'min_child_weight': 3, 'colsample_bytree': 0.2323201231321826, 'subsample': 0.6423192666070391, 'eta': 0.7834739304420851}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:46:54,455] Finished trial#94 resulted in value: 0.12288268072604733. Current best value is 0.11905349387227551 with parameters: {'max_depth': 4, 'n_estimators': 3006, 'max_features': 'log2', 'learning_rate': 0.008058401703663098, 'min_child_weight': 3, 'colsample_bytree': 0.2323201231321826, 'subsample': 0.6423192666070391, 'eta': 0.7834739304420851}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:47:48,634] Finished trial#97 resulted in value: 0.1258576917249008. Current best value is 0.11905349387227551 with parameters: {'max_depth': 4, 'n_estimators': 3006, 'max_features': 'log2', 'learning_rate': 0.008058401703663098, 'min_child_weight': 3, 'colsample_bytree': 0.2323201231321826, 'subsample': 0.6423192666070391, 'eta': 0.7834739304420851}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:47:51,373] Finished trial#96 resulted in value: 0.1278282958761709. Current best value is 0.11905349387227551 with parameters: {'max_depth': 4, 'n_estimators': 3006, 'max_features': 'log2', 'learning_rate': 0.008058401703663098, 'min_child_weight': 3, 'colsample_bytree': 0.2323201231321826, 'subsample': 0.6423192666070391, 'eta': 0.7834739304420851}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:48:09,924] Finished trial#98 resulted in value: 0.12107356877425209. Current best value is 0.11905349387227551 with parameters: {'max_depth': 4, 'n_estimators': 3006, 'max_features': 'log2', 'learning_rate': 0.008058401703663098, 'min_child_weight': 3, 'colsample_bytree': 0.2323201231321826, 'subsample': 0.6423192666070391, 'eta': 0.7834739304420851}.
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# [I 2019-05-23 04:48:26,733] Finished trial#99 resulted in value: 0.12216351570554626. Current best value is 0.11905349387227551 with parameters: {'max_depth': 4, 'n_estimators': 3006, 'max_features': 'log2', 'learning_rate': 0.008058401703663098, 'min_child_weight': 3, 'colsample_bytree': 0.2323201231321826, 'subsample': 0.6423192666070391, 'eta': 0.7834739304420851}.

# %%
'''
モデルの構築
'''
model = XGBRegressor(
        max_depth = 4,
        n_estimators =2385,
        max_features = 'auto',
        learning_rate = 0.021049677273288197,
        min_child_weight= 1, 
        colsample_bytree=0.17604967495337845, 
        subsample=0.852736097498378, 
        eta=0.2916808727686327, 
        n_jobs=-1,
        random_state = 1
    )

# %%
from sklearn.model_selection import cross_val_score
kf = KFold(5, shuffle=True, random_state=1).get_n_splits(X_train)
rmse = np.sqrt(-cross_val_score(model, X_train,Y_train, scoring="neg_mean_squared_error", cv=kf, verbose=0))
print('rmse:',rmse.mean())
# Out:
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
# rmse: 0.11838244070959343

# %%
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py:588: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bytree=0.17604967495337845, eta=0.2916808727686327,
#              gamma=0, importance_type='gain',
#              learning_rate=0.021049677273288197, max_delta_step=0, max_depth=4,
#              max_features='auto', min_child_weight=1, missing=None,
#              n_estimators=2385, n_jobs=-1, nthread=None, objective='reg:linear',
#              random_state=1, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#              seed=None, silent=True, subsample=0.852736097498378)

# %%
'''
提出
'''
predicted_prices = np.expm1(model.predict(X_test))
print(predicted_prices[:5])

my_submission = pd.DataFrame({'Id': Id, 'SalePrice': predicted_prices})
my_submission.Id = my_submission.Id.astype(int)
my_submission.to_csv('submission.csv', index=False)
# Out:
# [123728.61 160061.14 192825.69 194984.47 187178.61]
