# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('../tools/')
import tools

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')
x_train = train.drop(['SalePrice', 'Id'],axis=1)
y_train = train.SalePrice
x_test = test.drop(['Id'],axis=1)

# %%
prc = tools.Process(x_train,x_test,y_train)

# %% [markdown]
# # Observation

# %% [markdown]
# ## Focus on target variable

# %% [markdown]
# First, we create histgrams to see if the target variable is Normally distributed. \
# If we want to create [any linear model, it is essential that the features are normally distributed]. \
# This is one of the assumptions of multiple linear regression.
#
# [any linear model, it is essential that the features are normally distributed]:http://cogpsy.educ.kyoto-u.ac.jp/personal/Kusumi/datasem11/goto.pdf

# %%
prc.viewY()
# Out:
# SalePrice has 0 NaNs (0.00%).
# Skewness : 1.88
# Kurtosis : 6.54
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# These informations can tell us a lot about our target variable.
# - Our target variable, **SalePrice** is not normally distributed.
# - Our taget variable is right-skewed.
# - There are multiple outliers in the variable.

# %% [markdown]
# Next, find out the relationships among the target variable and other predictor variables.

# %%
prc.CorrY(view_set_top=10,bar=False)
# Out:
#                 |corr|
# Features
# OverallQual   0.790982
# GrLivArea     0.708624
# GarageCars    0.640409
# GarageArea    0.623431
# TotalBsmtSF   0.613581
# 1stFlrSF      0.605852
# FullBath      0.560664
# TotRmsAbvGrd  0.533723
# YearBuilt     0.522897
# YearRemodAdd  0.507101

# %% [markdown]
# The most correlated variable is **OverallQual**. \
# Let's put top variables in a scatter plot and see how them look.

# %%
prc.CorrY(view_set=False,bar=False,plot=True)
# Out:
# OverallQual has 0 NaNs (0.00%).
# Correlation Coefficient (OverallQual vs SalePrice): 0.791
# Skewness : 0.20
# Kurtosis : 0.07
# Number of anomaly scores over threshold(1.0%) : 17 / 2919
# Border line :  1.0
# ----------------------------------------------------------------------------------------------------
# GrLivArea has 0 NaNs (0.00%).
# Correlation Coefficient (GrLivArea vs SalePrice): 0.709
# Skewness : 1.27
# Kurtosis : 4.12
# Number of anomaly scores over threshold(1.0%) : 30 / 2919
# Border line :  2944.0
# ----------------------------------------------------------------------------------------------------
# GarageCars has 1 NaNs (0.03%).
# Correlation Coefficient (GarageCars vs SalePrice): 0.640
# Skewness : -0.22
# Kurtosis : 0.24
# Number of anomaly scores over threshold(1.0%) : 17 / 2919
# Border line :  4.0
# ----------------------------------------------------------------------------------------------------
# GarageArea has 1 NaNs (0.03%).
# Correlation Coefficient (GarageArea vs SalePrice): 0.623
# Skewness : 0.24
# Kurtosis : 0.94
# Number of anomaly scores over threshold(1.0%) : 21 / 2919
# Border line :  1085.0
# ----------------------------------------------------------------------------------------------------
# TotalBsmtSF has 1 NaNs (0.03%).
# Correlation Coefficient (TotalBsmtSF vs SalePrice): 0.614
# Skewness : 1.16
# Kurtosis : 9.15
# Number of anomaly scores over threshold(1.0%) : 23 / 2919
# Border line :  2320.0
# ----------------------------------------------------------------------------------------------------
# 1stFlrSF has 0 NaNs (0.00%).
# Correlation Coefficient (1stFlrSF vs SalePrice): 0.606
# Skewness : 1.47
# Kurtosis : 6.96
# Number of anomaly scores over threshold(1.0%) : 32 / 2919
# Border line :  2276.0
# ----------------------------------------------------------------------------------------------------
# FullBath has 0 NaNs (0.00%).
# Correlation Coefficient (FullBath vs SalePrice): 0.561
# Skewness : 0.17
# Kurtosis : -0.54
# Number of anomaly scores over threshold(1.0%) : 16 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# TotRmsAbvGrd has 0 NaNs (0.00%).
# Correlation Coefficient (TotRmsAbvGrd vs SalePrice): 0.534
# Skewness : 0.76
# Kurtosis : 1.17
# Number of anomaly scores over threshold(1.0%) : 52 / 2919
# Border line :  2.0
# ----------------------------------------------------------------------------------------------------
# YearBuilt has 0 NaNs (0.00%).
# Correlation Coefficient (YearBuilt vs SalePrice): 0.523
# Skewness : -0.60
# Kurtosis : -0.51
# Number of anomaly scores over threshold(1.0%) : 11 / 2919
# Border line :  1872.0
# ----------------------------------------------------------------------------------------------------
# YearRemodAdd has 0 NaNs (0.00%).
# Correlation Coefficient (YearRemodAdd vs SalePrice): 0.507
# Skewness : -0.45
# Kurtosis : -1.35
# Number of anomaly scores over threshold(1.0%) : 0 / 2919
# ----------------------------------------------------------------------------------------------------
# GarageYrBlt has 159 NaNs (5.45%).
# Correlation Coefficient (GarageYrBlt vs SalePrice): 0.486
# Skewness : -0.38
# Kurtosis : 1.81
# Number of anomaly scores over threshold(1.0%) : 11 / 2919
# Border line :  1895.0
# ----------------------------------------------------------------------------------------------------
# MasVnrArea has 23 NaNs (0.79%).
# Correlation Coefficient (MasVnrArea vs SalePrice): 0.477
# Skewness : 2.60
# Kurtosis : 9.25
# Number of anomaly scores over threshold(1.0%) : 72 / 2919
# Border line :  604.0
# ----------------------------------------------------------------------------------------------------
# Fireplaces has 0 NaNs (0.00%).
# Correlation Coefficient (Fireplaces vs SalePrice): 0.467
# Skewness : 0.73
# Kurtosis : 0.08
# Number of anomaly scores over threshold(1.0%) : 12 / 2919
# Border line :  3.0
# ----------------------------------------------------------------------------------------------------
# BsmtFinSF1 has 1 NaNs (0.03%).
# Correlation Coefficient (BsmtFinSF1 vs SalePrice): 0.386
# Skewness : 1.43
# Kurtosis : 6.90
# Number of anomaly scores over threshold(1.0%) : 23 / 2919
# Border line :  1721.0
# ----------------------------------------------------------------------------------------------------
# LotFrontage has 486 NaNs (16.65%).
# Correlation Coefficient (LotFrontage vs SalePrice): 0.352
# Skewness : 1.50
# Kurtosis : 11.30
# Number of anomaly scores over threshold(1.0%) : 40 / 2919
# Border line :  129.0
# ----------------------------------------------------------------------------------------------------
# WoodDeckSF has 0 NaNs (0.00%).
# Correlation Coefficient (WoodDeckSF vs SalePrice): 0.324
# Skewness : 1.84
# Kurtosis : 6.74
# Number of anomaly scores over threshold(1.0%) : 52 / 2919
# Border line :  450.0
# ----------------------------------------------------------------------------------------------------
# 2ndFlrSF has 0 NaNs (0.00%).
# Correlation Coefficient (2ndFlrSF vs SalePrice): 0.319
# Skewness : 0.86
# Kurtosis : -0.42
# Number of anomaly scores over threshold(1.0%) : 17 / 2919
# Border line :  1540.0
# ----------------------------------------------------------------------------------------------------
# OpenPorchSF has 0 NaNs (0.00%).
# Correlation Coefficient (OpenPorchSF vs SalePrice): 0.316
# Skewness : 2.54
# Kurtosis : 10.94
# Number of anomaly scores over threshold(1.0%) : 67 / 2919
# Border line :  238.0
# ----------------------------------------------------------------------------------------------------
# HalfBath has 0 NaNs (0.00%).
# Correlation Coefficient (HalfBath vs SalePrice): 0.284
# Skewness : 0.69
# Kurtosis : -1.03
# Number of anomaly scores over threshold(1.0%) : 25 / 2919
# Border line :  2.0
# ----------------------------------------------------------------------------------------------------
# LotArea has 0 NaNs (0.00%).
# Correlation Coefficient (LotArea vs SalePrice): 0.264
# Skewness : 12.83
# Kurtosis : 264.95
# Number of anomaly scores over threshold(1.0%) : 32 / 2919
# Border line :  32463.0
# ----------------------------------------------------------------------------------------------------
# BsmtFullBath has 2 NaNs (0.07%).
# Correlation Coefficient (BsmtFullBath vs SalePrice): 0.227
# Skewness : 0.62
# Kurtosis : -0.74
# Number of anomaly scores over threshold(1.0%) : 40 / 2919
# Border line :  2.0
# ----------------------------------------------------------------------------------------------------
# BsmtUnfSF has 1 NaNs (0.03%).
# Correlation Coefficient (BsmtUnfSF vs SalePrice): 0.214
# Skewness : 0.92
# Kurtosis : 0.40
# Number of anomaly scores over threshold(1.0%) : 28 / 2919
# Border line :  1795.0
# ----------------------------------------------------------------------------------------------------
# BedroomAbvGr has 0 NaNs (0.00%).
# Correlation Coefficient (BedroomAbvGr vs SalePrice): 0.168
# Skewness : 0.33
# Kurtosis : 1.94
# Number of anomaly scores over threshold(1.0%) : 30 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# KitchenAbvGr has 0 NaNs (0.00%).
# Correlation Coefficient (KitchenAbvGr vs SalePrice): -0.136
# Skewness : 4.30
# Kurtosis : 19.78
# Number of anomaly scores over threshold(1.0%) : 134 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# EnclosedPorch has 0 NaNs (0.00%).
# Correlation Coefficient (EnclosedPorch vs SalePrice): -0.129
# Skewness : 4.01
# Kurtosis : 28.38
# Number of anomaly scores over threshold(1.0%) : 105 / 2919
# Border line :  204.0
# ----------------------------------------------------------------------------------------------------
# ScreenPorch has 0 NaNs (0.00%).
# Correlation Coefficient (ScreenPorch vs SalePrice): 0.111
# Skewness : 3.95
# Kurtosis : 17.78
# Number of anomaly scores over threshold(1.0%) : 126 / 2919
# Border line :  174.0
# ----------------------------------------------------------------------------------------------------
# PoolArea has 0 NaNs (0.00%).
# Correlation Coefficient (PoolArea vs SalePrice): 0.092
# Skewness : 16.91
# Kurtosis : 298.63
# Number of anomaly scores over threshold(1.0%) : 13 / 2919
# Border line :  144.0
# ----------------------------------------------------------------------------------------------------
# MSSubClass has 0 NaNs (0.00%).
# Correlation Coefficient (MSSubClass vs SalePrice): -0.084
# Skewness : 1.38
# Kurtosis : 1.46
# Number of anomaly scores over threshold(1.0%) : 78 / 2919
# Border line :  180.0
# ----------------------------------------------------------------------------------------------------
# OverallCond has 0 NaNs (0.00%).
# Correlation Coefficient (OverallCond vs SalePrice): -0.078
# Skewness : 0.57
# Kurtosis : 1.48
# Number of anomaly scores over threshold(1.0%) : 58 / 2919
# Border line :  1.0
# ----------------------------------------------------------------------------------------------------
# MoSold has 0 NaNs (0.00%).
# Correlation Coefficient (MoSold vs SalePrice): 0.046
# Skewness : 0.20
# Kurtosis : -0.45
# Number of anomaly scores over threshold(1.0%) : 0 / 2919
# ----------------------------------------------------------------------------------------------------
# 3SsnPorch has 0 NaNs (0.00%).
# Correlation Coefficient (3SsnPorch vs SalePrice): 0.045
# Skewness : 11.38
# Kurtosis : 149.41
# Number of anomaly scores over threshold(1.0%) : 36 / 2919
# Border line :  86.0
# ----------------------------------------------------------------------------------------------------
# YrSold has 0 NaNs (0.00%).
# Correlation Coefficient (YrSold vs SalePrice): -0.029
# Skewness : 0.13
# Kurtosis : -1.16
# Number of anomaly scores over threshold(1.0%) : 0 / 2919
# ----------------------------------------------------------------------------------------------------
# LowQualFinSF has 0 NaNs (0.00%).
# Correlation Coefficient (LowQualFinSF vs SalePrice): -0.026
# Skewness : 12.09
# Kurtosis : 174.93
# Number of anomaly scores over threshold(1.0%) : 32 / 2919
# Border line :  140.0
# ----------------------------------------------------------------------------------------------------
# MiscVal has 0 NaNs (0.00%).
# Correlation Coefficient (MiscVal vs SalePrice): -0.021
# Skewness : 21.96
# Kurtosis : 564.07
# Number of anomaly scores over threshold(1.0%) : 19 / 2919
# Border line :  2000.0
# ----------------------------------------------------------------------------------------------------
# BsmtHalfBath has 2 NaNs (0.07%).
# Correlation Coefficient (BsmtHalfBath vs SalePrice): -0.017
# Skewness : 3.93
# Kurtosis : 14.85
# Number of anomaly scores over threshold(1.0%) : 175 / 2919
# Border line :  1.0
# ----------------------------------------------------------------------------------------------------
# BsmtFinSF2 has 1 NaNs (0.03%).
# Correlation Coefficient (BsmtFinSF2 vs SalePrice): -0.011
# Skewness : 4.15
# Kurtosis : 18.84
# Number of anomaly scores over threshold(1.0%) : 107 / 2919
# Border line :  529.0
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Let's check out some high correlated features to determine the outliers.
# - **SalePrice vs OverallQual** \
# Clearly, OverallQual is a categorical variable and scatter plot is not the best way to visualize categorical variables. \
# However, it looks like <u>some of the houses are overpriced compared to their overall quality</u>.\
# These could be outliers.
# - **SalePrice vs GrLivArea** \
# As you can see <u>there are two outliers</u> in the plot above. \
# We will get rid off them later.

# %% [markdown]
# **Observations**
# - Our target variable shows an unequal level of variance across most predictor(independent) variable values.\
#   This is called [Heteroscedasticity] and is a red flag for the multiple linear regression model.
# -
#
# [Heteroscedasticity]:https://ja.wikipedia.org/wiki/%E7%AD%89%E5%88%86%E6%95%A3%E6%80%A7

# %% [markdown]
# # References

# %% [markdown]
# - referenced kernel
# https://www.kaggle.com/masumrumi/a-detailed-regression-guide-with-house-pricing
# - normality of distribution
# http://cogpsy.educ.kyoto-u.ac.jp/personal/Kusumi/datasem11/goto.pdf
# - Skewness and Kurtosis
# https://codeburst.io/2-important-statistics-terms-you-need-to-know-in-data-science-skewness-and-kurtosis-388fef94eeaa
# https://toukeigaku-jouhou.info/2017/08/20/kurtosis/
# - Heteroscedasticity
# https://ja.wikipedia.org/wiki/%E7%AD%89%E5%88%86%E6%95%A3%E6%80%A7
