# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('../tools/')

# %%
import tools

# %% [markdown]
# # Load Data

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')
x_train = train.drop(['SalePrice', 'Id'],axis=1)
y_train = train.SalePrice
x_test = test.drop(['Id'],axis=1)

# %%
prc = tools.Preprocess(x_train,x_test,y_train)

# %% [markdown]
# # Analyse

# %% [markdown]
# ## Overview

# %%
prc.view(dtype='int',significance=0.01)
# Out:
# MSSubClass has 0 NaNs (0.00%).
# Correlation Coefficient (MSSubClass vs target): -0.08428413512659523
# Skewness :  1.3761646373261713
# Kurtosis :  1.4578274774335522
# Number of anomaly scores over threshold(1.0%) : 78 / 2919
# Border line :  180.0
# ----------------------------------------------------------------------------------------------------
# MSZoning has 0 NaNs (0.00%).
# Correlation Coefficient (MSZoning vs target): -0.1402539059615727
# Skewness :  -2.5751949104349707
# Kurtosis :  8.130899673130163
# Number of anomaly scores over threshold(1.0%) : 164 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# LotArea has 0 NaNs (0.00%).
# Correlation Coefficient (LotArea vs target): 0.2638433538714063
# Skewness :  12.829024853018762
# Kurtosis :  264.95231013978935
# Number of anomaly scores over threshold(1.0%) : 32 / 2919
# Border line :  32463.0
# ----------------------------------------------------------------------------------------------------
# Street has 0 NaNs (0.00%).
# Correlation Coefficient (Street vs target): 0.04103553550004989
# Skewness :  -15.508103518194476
# Kurtosis :  238.66479934219134
# Number of anomaly scores over threshold(1.0%) : 12 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# Alley has 0 NaNs (0.00%).
# Correlation Coefficient (Alley vs target): 0.08312112052038152
# Skewness :  -0.6523755724485645
# Kurtosis :  11.692213170735037
# Number of anomaly scores over threshold(1.0%) : 198 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# LotShape has 0 NaNs (0.00%).
# Correlation Coefficient (LotShape vs target): -0.2555798704871257
# Skewness :  -0.6180074661788829
# Kurtosis :  -1.5884910090780502
# Number of anomaly scores over threshold(1.0%) : 0 / 2919
# ----------------------------------------------------------------------------------------------------
# LandContour has 0 NaNs (0.00%).
# Correlation Coefficient (LandContour vs target): 0.01545324166096035
# Skewness :  -3.1182954145754334
# Kurtosis :  8.411244372086632
# Number of anomaly scores over threshold(1.0%) : 117 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# Utilities has 0 NaNs (0.00%).
# Correlation Coefficient (Utilities vs target): -0.014314296147248952
# Skewness :  36.73981241572967
# Kurtosis :  1457.220190917926
# Number of anomaly scores over threshold(1.0%) : 3 / 2919
# Border line :  1.0
# ----------------------------------------------------------------------------------------------------
# LotConfig has 0 NaNs (0.00%).
# Correlation Coefficient (LotConfig vs target): -0.06739602315941719
# Skewness :  -1.1969012059819362
# Kurtosis :  -0.4378763485559487
# Number of anomaly scores over threshold(1.0%) : 0 / 2919
# ----------------------------------------------------------------------------------------------------
# LandSlope has 0 NaNs (0.00%).
# Correlation Coefficient (LandSlope vs target): 0.05115224817946586
# Skewness :  4.977715123085601
# Kurtosis :  26.5753647232301
# Number of anomaly scores over threshold(1.0%) : 141 / 2919
# Border line :  1.0
# ----------------------------------------------------------------------------------------------------
# Neighborhood has 0 NaNs (0.00%).
# Correlation Coefficient (Neighborhood vs target): 0.21085146582230405
# Skewness :  0.01626935770093015
# Kurtosis :  -1.063213813203717
# Number of anomaly scores over threshold(1.0%) : 0 / 2919
# ----------------------------------------------------------------------------------------------------
# Condition1 has 0 NaNs (0.00%).
# Correlation Coefficient (Condition1 vs target): 0.09115491154092925
# Skewness :  2.984648411273289
# Kurtosis :  15.70810799023976
# Number of anomaly scores over threshold(1.0%) : 93 / 2919
# Border line :  5.0
# ----------------------------------------------------------------------------------------------------
# Condition2 has 0 NaNs (0.00%).
# Correlation Coefficient (Condition2 vs target): 0.007512734036333074
# Skewness :  12.066294147728463
# Kurtosis :  308.54272145875467
# Number of anomaly scores over threshold(1.0%) : 30 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# BldgType has 0 NaNs (0.00%).
# Correlation Coefficient (BldgType vs target): -0.08559060818352893
# Skewness :  2.1933884721231625
# Kurtosis :  3.1984562705466386
# Number of anomaly scores over threshold(1.0%) : 227 / 2919
# Border line :  4.0
# ----------------------------------------------------------------------------------------------------
# HouseStyle has 0 NaNs (0.00%).
# Correlation Coefficient (HouseStyle vs target): 0.18016262334399255
# Skewness :  0.3172593354155327
# Kurtosis :  -0.9530628419613936
# Number of anomaly scores over threshold(1.0%) : 0 / 2919
# ----------------------------------------------------------------------------------------------------
# OverallQual has 0 NaNs (0.00%).
# Correlation Coefficient (OverallQual vs target): 0.7909816005838047
# Skewness :  0.19721180528040133
# Kurtosis :  0.06721935990514183
# Number of anomaly scores over threshold(1.0%) : 17 / 2919
# Border line :  1.0
# ----------------------------------------------------------------------------------------------------
# OverallCond has 0 NaNs (0.00%).
# Correlation Coefficient (OverallCond vs target): -0.0778558940486776
# Skewness :  0.5706053117352524
# Kurtosis :  1.4794473338247043
# Number of anomaly scores over threshold(1.0%) : 58 / 2919
# Border line :  1.0
# ----------------------------------------------------------------------------------------------------
# YearBuilt has 0 NaNs (0.00%).
# Correlation Coefficient (YearBuilt vs target): 0.5228973328794967
# Skewness :  -0.6001139748696814
# Kurtosis :  -0.5113172970570274
# Number of anomaly scores over threshold(1.0%) : 11 / 2919
# Border line :  1872.0
# ----------------------------------------------------------------------------------------------------
# YearRemodAdd has 0 NaNs (0.00%).
# Correlation Coefficient (YearRemodAdd vs target): 0.5071009671113867
# Skewness :  -0.45125229728739846
# Kurtosis :  -1.3464313917613444
# Number of anomaly scores over threshold(1.0%) : 0 / 2919
# ----------------------------------------------------------------------------------------------------
# RoofStyle has 0 NaNs (0.00%).
# Correlation Coefficient (RoofStyle vs target): 0.22240529240713802
# Skewness :  1.55410559757861
# Kurtosis :  0.8751310003918631
# Number of anomaly scores over threshold(1.0%) : 16 / 2919
# Border line :  4.0
# ----------------------------------------------------------------------------------------------------
# RoofMatl has 0 NaNs (0.00%).
# Correlation Coefficient (RoofMatl vs target): 0.1323831119277861
# Skewness :  8.712244641552445
# Kurtosis :  76.86029753657262
# Number of anomaly scores over threshold(1.0%) : 41 / 2919
# Border line :  3.0
# ----------------------------------------------------------------------------------------------------
# Exterior1st has 0 NaNs (0.00%).
# Correlation Coefficient (Exterior1st vs target): 0.1121945403547806
# Skewness :  -0.6518755016591912
# Kurtosis :  -0.674594023790152
# Number of anomaly scores over threshold(1.0%) : 44 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# Exterior2nd has 0 NaNs (0.00%).
# Correlation Coefficient (Exterior2nd vs target): 0.10813260202422924
# Skewness :  -0.6337435176073184
# Kurtosis :  -0.8253189529961626
# Number of anomaly scores over threshold(1.0%) : 0 / 2919
# ----------------------------------------------------------------------------------------------------
# MasVnrType has 0 NaNs (0.00%).
# Correlation Coefficient (MasVnrType vs target): -0.0759432800095676
# Skewness :  -0.563636239476423
# Kurtosis :  -1.0974150083428722
# Number of anomaly scores over threshold(1.0%) : 0 / 2919
# ----------------------------------------------------------------------------------------------------
# ExterQual has 0 NaNs (0.00%).
# Correlation Coefficient (ExterQual vs target): -0.6368836943991124
# Skewness :  -1.8023350602173602
# Kurtosis :  3.6979016265584432
# Number of anomaly scores over threshold(1.0%) : 107 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# ExterCond has 0 NaNs (0.00%).
# Correlation Coefficient (ExterCond vs target): 0.11730265704316599
# Skewness :  -2.499003007152112
# Kurtosis :  5.0936823669417
# Number of anomaly scores over threshold(1.0%) : 79 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# Foundation has 0 NaNs (0.00%).
# Correlation Coefficient (Foundation vs target): 0.38247899119010337
# Skewness :  0.00758166130434793
# Kurtosis :  0.7565316264597195
# Number of anomaly scores over threshold(1.0%) : 16 / 2919
# Border line :  4.0
# ----------------------------------------------------------------------------------------------------
# BsmtQual has 0 NaNs (0.00%).
# Correlation Coefficient (BsmtQual vs target): -0.5937339191038178
# Skewness :  -0.4885240812763102
# Kurtosis :  -0.7650997608742385
# Number of anomaly scores over threshold(1.0%) : 0 / 2919
# ----------------------------------------------------------------------------------------------------
# BsmtCond has 0 NaNs (0.00%).
# Correlation Coefficient (BsmtCond vs target): 0.09150303200495925
# Skewness :  -2.864057228732265
# Kurtosis :  6.747415742596279
# Number of anomaly scores over threshold(1.0%) : 104 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# BsmtExposure has 0 NaNs (0.00%).
# Correlation Coefficient (BsmtExposure vs target): -0.2745890433483174
# Skewness :  -1.1231562068765704
# Kurtosis :  -0.47964343963489986
# Number of anomaly scores over threshold(1.0%) : 0 / 2919
# ----------------------------------------------------------------------------------------------------
# BsmtFinType1 has 0 NaNs (0.00%).
# Correlation Coefficient (BsmtFinType1 vs target): -0.09873436814720812
# Skewness :  0.08467626575377352
# Kurtosis :  -1.5093273875403899
# Number of anomaly scores over threshold(1.0%) : 0 / 2919
# ----------------------------------------------------------------------------------------------------
# BsmtFinType2 has 0 NaNs (0.00%).
# Correlation Coefficient (BsmtFinType2 vs target): 0.07271749455212063
# Skewness :  -3.045893331027733
# Kurtosis :  8.501851112010893
# Number of anomaly scores over threshold(1.0%) : 120 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# Heating has 0 NaNs (0.00%).
# Correlation Coefficient (Heating vs target): -0.0988120759975766
# Skewness :  12.08499889808365
# Kurtosis :  168.20956899388207
# Number of anomaly scores over threshold(1.0%) : 45 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# HeatingQC has 0 NaNs (0.00%).
# Correlation Coefficient (HeatingQC vs target): -0.4001775431629018
# Skewness :  0.48690624436583385
# Kurtosis :  -1.5128781161717462
# Number of anomaly scores over threshold(1.0%) : 0 / 2919
# ----------------------------------------------------------------------------------------------------
# CentralAir has 0 NaNs (0.00%).
# Correlation Coefficient (CentralAir vs target): 0.2513281638401573
# Skewness :  -3.4608011604759965
# Kurtosis :  9.98398489286317
# Number of anomaly scores over threshold(1.0%) : 196 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# Electrical has 0 NaNs (0.00%).
# Correlation Coefficient (Electrical vs target): 0.23639137221829445
# Skewness :  -3.04938186595119
# Kurtosis :  7.412729710945849
# Number of anomaly scores over threshold(1.0%) : 188 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# 1stFlrSF has 0 NaNs (0.00%).
# Correlation Coefficient (1stFlrSF vs target): 0.6058521846919166
# Skewness :  1.4703601055379227
# Kurtosis :  6.956479038030847
# Number of anomaly scores over threshold(1.0%) : 32 / 2919
# Border line :  2276.0
# ----------------------------------------------------------------------------------------------------
# 2ndFlrSF has 0 NaNs (0.00%).
# Correlation Coefficient (2ndFlrSF vs target): 0.31933380283206614
# Skewness :  0.8621178325657642
# Kurtosis :  -0.4222606698937579
# Number of anomaly scores over threshold(1.0%) : 17 / 2919
# Border line :  1540.0
# ----------------------------------------------------------------------------------------------------
# LowQualFinSF has 0 NaNs (0.00%).
# Correlation Coefficient (LowQualFinSF vs target): -0.02560613000068015
# Skewness :  12.094977192517302
# Kurtosis :  174.93281241177277
# Number of anomaly scores over threshold(1.0%) : 32 / 2919
# Border line :  140.0
# ----------------------------------------------------------------------------------------------------
# GrLivArea has 0 NaNs (0.00%).
# Correlation Coefficient (GrLivArea vs target): 0.7086244776126511
# Skewness :  1.2700104075191514
# Kurtosis :  4.121603735289667
# Number of anomaly scores over threshold(1.0%) : 30 / 2919
# Border line :  2944.0
# ----------------------------------------------------------------------------------------------------
# FullBath has 0 NaNs (0.00%).
# Correlation Coefficient (FullBath vs target): 0.5606637627484452
# Skewness :  0.16769191818882379
# Kurtosis :  -0.5381293607434401
# Number of anomaly scores over threshold(1.0%) : 16 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# HalfBath has 0 NaNs (0.00%).
# Correlation Coefficient (HalfBath vs target): 0.2841076755947784
# Skewness :  0.6949236492716564
# Kurtosis :  -1.0334464798987986
# Number of anomaly scores over threshold(1.0%) : 25 / 2919
# Border line :  2.0
# ----------------------------------------------------------------------------------------------------
# BedroomAbvGr has 0 NaNs (0.00%).
# Correlation Coefficient (BedroomAbvGr vs target): 0.1682131543007415
# Skewness :  0.32649214927079917
# Kurtosis :  1.9414037478968682
# Number of anomaly scores over threshold(1.0%) : 30 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# KitchenAbvGr has 0 NaNs (0.00%).
# Correlation Coefficient (KitchenAbvGr vs target): -0.1359073708421417
# Skewness :  4.304466641562935
# Kurtosis :  19.77793659070052
# Number of anomaly scores over threshold(1.0%) : 134 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# KitchenQual has 0 NaNs (0.00%).
# Correlation Coefficient (KitchenQual vs target): -0.5911752847263703
# Skewness :  -0.6258980648484331
# Kurtosis :  -0.6726228143491122
# Number of anomaly scores over threshold(1.0%) : 0 / 2919
# ----------------------------------------------------------------------------------------------------
# TotRmsAbvGrd has 0 NaNs (0.00%).
# Correlation Coefficient (TotRmsAbvGrd vs target): 0.5337231555820238
# Skewness :  0.7587568676624701
# Kurtosis :  1.169063585207879
# Number of anomaly scores over threshold(1.0%) : 52 / 2919
# Border line :  2.0
# ----------------------------------------------------------------------------------------------------
# Functional has 0 NaNs (0.00%).
# Correlation Coefficient (Functional vs target): 0.11677396159478325
# Skewness :  -3.957737402839217
# Kurtosis :  14.904582270796723
# Number of anomaly scores over threshold(1.0%) : 163 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# Fireplaces has 0 NaNs (0.00%).
# Correlation Coefficient (Fireplaces vs target): 0.4669288367515242
# Skewness :  0.733871770878103
# Kurtosis :  0.07642384075687625
# Number of anomaly scores over threshold(1.0%) : 12 / 2919
# Border line :  3.0
# ----------------------------------------------------------------------------------------------------
# FireplaceQu has 0 NaNs (0.00%).
# Correlation Coefficient (FireplaceQu vs target): -0.09717638681344758
# Skewness :  0.33395902206642486
# Kurtosis :  -0.1282294021122361
# Number of anomaly scores over threshold(1.0%) : 0 / 2919
# ----------------------------------------------------------------------------------------------------
# GarageType has 0 NaNs (0.00%).
# Correlation Coefficient (GarageType vs target): -0.41528306845290286
# Skewness :  0.6331143754411049
# Kurtosis :  -1.4147263838593582
# Number of anomaly scores over threshold(1.0%) : 0 / 2919
# ----------------------------------------------------------------------------------------------------
# GarageFinish has 0 NaNs (0.00%).
# Correlation Coefficient (GarageFinish vs target): -0.4256842542080429
# Skewness :  -0.608345229508571
# Kurtosis :  -1.2056513928693806
# Number of anomaly scores over threshold(1.0%) : 0 / 2919
# ----------------------------------------------------------------------------------------------------
# GarageQual has 0 NaNs (0.00%).
# Correlation Coefficient (GarageQual vs target): 0.20596282894354684
# Skewness :  -3.075732443398575
# Kurtosis :  8.372586312054306
# Number of anomaly scores over threshold(1.0%) : 151 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# GarageCond has 0 NaNs (0.00%).
# Correlation Coefficient (GarageCond vs target): 0.2467052743716152
# Skewness :  -3.5976385824451707
# Kurtosis :  12.547334375886233
# Number of anomaly scores over threshold(1.0%) : 92 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# PavedDrive has 0 NaNs (0.00%).
# Correlation Coefficient (PavedDrive vs target): 0.23135695225722583
# Skewness :  -2.980616074119485
# Kurtosis :  7.125856426285172
# Number of anomaly scores over threshold(1.0%) : 216 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# WoodDeckSF has 0 NaNs (0.00%).
# Correlation Coefficient (WoodDeckSF vs target): 0.32441344456813076
# Skewness :  1.8433802126628294
# Kurtosis :  6.741550189823774
# Number of anomaly scores over threshold(1.0%) : 52 / 2919
# Border line :  450.0
# ----------------------------------------------------------------------------------------------------
# OpenPorchSF has 0 NaNs (0.00%).
# Correlation Coefficient (OpenPorchSF vs target): 0.31585622711605577
# Skewness :  2.5364173160468444
# Kurtosis :  10.937352524991375
# Number of anomaly scores over threshold(1.0%) : 67 / 2919
# Border line :  238.0
# ----------------------------------------------------------------------------------------------------
# EnclosedPorch has 0 NaNs (0.00%).
# Correlation Coefficient (EnclosedPorch vs target): -0.12857795792595636
# Skewness :  4.005950070504265
# Kurtosis :  28.377908922009446
# Number of anomaly scores over threshold(1.0%) : 105 / 2919
# Border line :  204.0
# ----------------------------------------------------------------------------------------------------
# 3SsnPorch has 0 NaNs (0.00%).
# Correlation Coefficient (3SsnPorch vs target): 0.04458366533574792
# Skewness :  11.381914394786643
# Kurtosis :  149.4098342664387
# Number of anomaly scores over threshold(1.0%) : 36 / 2919
# Border line :  86.0
# ----------------------------------------------------------------------------------------------------
# ScreenPorch has 0 NaNs (0.00%).
# Correlation Coefficient (ScreenPorch vs target): 0.11144657114291048
# Skewness :  3.948723141292199
# Kurtosis :  17.77670360587794
# Number of anomaly scores over threshold(1.0%) : 126 / 2919
# Border line :  174.0
# ----------------------------------------------------------------------------------------------------
# PoolArea has 0 NaNs (0.00%).
# Correlation Coefficient (PoolArea vs target): 0.09240354949187278
# Skewness :  16.9070172435751
# Kurtosis :  298.6331435760181
# Number of anomaly scores over threshold(1.0%) : 13 / 2919
# Border line :  144.0
# ----------------------------------------------------------------------------------------------------
# PoolQC has 0 NaNs (0.00%).
# Correlation Coefficient (PoolQC vs target): -0.1260697386353289
# Skewness :  -20.734650329860763
# Kurtosis :  452.03236049840865
# Number of anomaly scores over threshold(1.0%) : 10 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# Fence has 0 NaNs (0.00%).
# Correlation Coefficient (Fence vs target): -0.05431780147772984
# Skewness :  -1.1539208467381654
# Kurtosis :  4.9926624237153385
# Number of anomaly scores over threshold(1.0%) : 130 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# MiscFeature has 0 NaNs (0.00%).
# Correlation Coefficient (MiscFeature vs target): -0.06631614899148028
# Skewness :  5.066924804667525
# Kurtosis :  24.82449556767918
# Number of anomaly scores over threshold(1.0%) : 101 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# MiscVal has 0 NaNs (0.00%).
# Correlation Coefficient (MiscVal vs target): -0.02118957964030379
# Skewness :  21.958480324447216
# Kurtosis :  564.0745817668892
# Number of anomaly scores over threshold(1.0%) : 19 / 2919
# Border line :  2000.0
# ----------------------------------------------------------------------------------------------------
# MoSold has 0 NaNs (0.00%).
# Correlation Coefficient (MoSold vs target): 0.04643224522381936
# Skewness :  0.19598466898916275
# Kurtosis :  -0.4543365880455785
# Number of anomaly scores over threshold(1.0%) : 0 / 2919
# ----------------------------------------------------------------------------------------------------
# YrSold has 0 NaNs (0.00%).
# Correlation Coefficient (YrSold vs target): -0.028922585168730426
# Skewness :  0.13246689568568673
# Kurtosis :  -1.1551465584406364
# Number of anomaly scores over threshold(1.0%) : 0 / 2919
# ----------------------------------------------------------------------------------------------------
# SaleType has 0 NaNs (0.00%).
# Correlation Coefficient (SaleType vs target): -0.04014203590121788
# Skewness :  -3.802582252279275
# Kurtosis :  14.036786163720894
# Number of anomaly scores over threshold(1.0%) : 130 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------
# SaleCondition has 0 NaNs (0.00%).
# Correlation Coefficient (SaleCondition vs target): 0.21309202967780272
# Skewness :  -2.7894723560144894
# Kurtosis :  7.229054783087684
# Number of anomaly scores over threshold(1.0%) : 190 / 2919
# Border line :  0.0
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Missing Data

# %%
prc.NANs(top=10,bar=True,plot=False,get_return=False)

# %% [markdown]
# ## Skewness

# %%
prc.Skews(top=10,bar=True,plot=False,get_return=False)

# %% [markdown]
# ## Kurtosis

# %%
prc.Kurts(top=10,bar=True,plot=False,get_return=False)

# %% [markdown]
# # Preprocess

# %% [markdown]
# ## Fill NAN

# %%
# x_train_filled,x_test_filled, _ = prc.fill(
#     fill_method_num='median',
#     fill_method_object='Missing',
#     inplace=False,
#     get_return=True)
prc.fill(
    fill_method_num='median',
    fill_method_object='Missing',
    inplace=True,
    get_return=False)
# Out:
# Missing NAN of Numeric types is filled by : median.
# Missing NAN of Numeric types is filled by : Missing.

# %%
prc.x_train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0          60       RL         65.0     8450   Pave  Missing      Reg
# 1          20       RL         80.0     9600   Pave  Missing      Reg
# 2          60       RL         68.0    11250   Pave  Missing      IR1
# 3          70       RL         60.0     9550   Pave  Missing      IR1
# 4          60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities LotConfig  ... ScreenPorch PoolArea   PoolQC    Fence  \
# 0         Lvl    AllPub    Inside  ...           0        0  Missing  Missing
# 1         Lvl    AllPub       FR2  ...           0        0  Missing  Missing
# 2         Lvl    AllPub    Inside  ...           0        0  Missing  Missing
# 3         Lvl    AllPub    Corner  ...           0        0  Missing  Missing
# 4         Lvl    AllPub       FR2  ...           0        0  Missing  Missing
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0     Missing       0       2    2008        WD         Normal
# 1     Missing       0       5    2007        WD         Normal
# 2     Missing       0       9    2008        WD         Normal
# 3     Missing       0       2    2006        WD        Abnorml
# 4     Missing       0      12    2008        WD         Normal
#
# [5 rows x 79 columns]

# %%
print(prc.x_train.shape)
print(prc.x_test.shape)
print(prc.missing.sum())
# Out:
# (1460, 79)
# (1459, 79)
# 0

# %% [markdown]
# ## Encode to numeric

# %%
# x_train_encoded, x_test_encoded, _ = prc.encode(
#     method_enc='label', inplace=False, get_return=True)
prc.encode(method_enc='label', inplace=True, get_return=False)

# %%
prc.x_train.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0          60         4         65.0     8450       1      1         3
# 1          20         4         80.0     9600       1      1         3
# 2          60         4         68.0    11250       1      1         0
# 3          70         4         60.0     9550       1      1         0
# 4          60         4         84.0    14260       1      1         0
#
#    LandContour  Utilities  LotConfig  ...  ScreenPorch  PoolArea  PoolQC  \
# 0            3          0          4  ...            0         0       3
# 1            3          0          2  ...            0         0       3
# 2            3          0          4  ...            0         0       3
# 3            3          0          0  ...            0         0       3
# 4            3          0          2  ...            0         0       3
#
#    Fence  MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 0      2            1        0       2    2008         9              4
# 1      2            1        0       5    2007         9              4
# 2      2            1        0       9    2008         9              4
# 3      2            1        0       2    2006         9              0
# 4      2            1        0      12    2008         9              4
#
# [5 rows x 79 columns]

# %%
print(prc.x_train.shape)
print(prc.x_test.shape)
print(prc.x_all.dtypes.unique())
# Out:
# (1460, 79)
# (1459, 79)
# [dtype('int64') dtype('float64')]
