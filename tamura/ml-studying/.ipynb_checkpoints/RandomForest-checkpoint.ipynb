# %% [markdown]
# # Abstract

# %% [markdown]
# A random forest is a meta estimator that fits a number of decision tree classifiers or regressors on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting.
# The fundamental idea behind a random forest is to **combine many decision trees into a single model**. Individually, predictions made by decision trees may not be accurate, but combined together, **the predictions will be closer to the mark on average**.

# %% [markdown]
# # Theory

# %% [markdown]
# Random forest is **constructed by many decision trees, and their trees use random sample data sets individually**.
# Note, there data is sampled from origin features randomly and this way   forgive duplication. So, some data may be not used . Not used data is called **OOB (Out of Bag)**.
#
# These process is called as **bootstrap sampling (bagging)**. Bootstrap sampling increases diversity in the forest leading to more robust overall predictions.

# %% [markdown]
# # Boruta

# %% [markdown]
# https://aotamasaki.hatenablog.com/entry/2019/01/05/195813

# %% [markdown]
# # Imprementation

# %% [markdown]
# ## Basics

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn import metrics
from sklearn.metrics import mean_squared_error
import numpy as np
from matplotlib import pyplot as plt

# %%
boston = datasets.load_boston()
x = boston.data
y = boston.target
x_train, x_val, y_train, y_val = train_test_split(x, y, train_size=0.75)

# %%
model = RandomForestRegressor()
model.fit(x_train, y_train)
# Out:
# /home/yashima/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
y_pred = model.predict(x_val)
rmse = np.sqrt(mean_squared_error(y_val, y_pred))
print('RMSE : ', rmse)

fig, ax = plt.subplots(facecolor='w', figsize=(10,3))
ax.plot(y_val, marker = 'o', label='y_val')
ax.plot(y_pred, marker = 'x', label='y_pred')
ax.legend()
plt.show()
# Out:
# RMSE :  2.749128423085064

# %%
feature_importances = model.feature_importances_
print(feature_importances)

plt.figure(figsize=(10, 3))
plt.ylim([0, 1])
y = feature_importances
x = np.arange(len(y))
plt.bar(x, y, align="center")
plt.xticks(x, boston['feature_names'])
plt.show()
# Out:
# [0.01913307 0.00120699 0.00854434 0.00275559 0.01817813 0.32378022
#  0.00988392 0.07686858 0.00778461 0.01257456 0.01686605 0.00916645
#  0.49325749]

# %% [markdown]
# ## Advances

# %% [markdown]
# ### PCA approach

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn import metrics
from sklearn.metrics import mean_squared_error
import numpy as np
from matplotlib import pyplot as plt

# %%
from sklearn.decomposition import PCA

# %%
boston = datasets.load_boston()
x = boston.data
y = boston.target
x_train, x_val, y_train, y_val = train_test_split(x, y, train_size=0.75)

# %%
pca = PCA(n_components=13)
pca.fit(x_train)
plt.bar([n for n in range(1, len(pca.explained_variance_ratio_)+1)], pca.explained_variance_ratio_)
print('explained variance ratio: {}'.format(pca.explained_variance_ratio_))
# Out:
# explained variance ratio: [8.02451298e-01 1.65129871e-01 2.22836947e-02 7.01477529e-03
#  1.60290726e-03 7.22542731e-04 4.15096980e-04 2.60294345e-04
#  7.97620029e-05 3.08428965e-05 7.03366976e-06 1.80451894e-06
#  7.65917704e-08]

# %%
pca = PCA(n_components=5)
pca.fit(x_train)
x_train_pca = pca.transform(x_train)
x_val_pca = pca.transform(x_val)
print(x_train_pca.shape)
# Out:
# (379, 5)

# %%
model = RandomForestRegressor()
model.fit(x_train_pca, y_train)
# Out:
# /home/yashima/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
y_pred = model.predict(x_val_pca)
rmse = np.sqrt(mean_squared_error(y_val, y_pred))
print('RMSE : ', rmse)

fig, ax = plt.subplots(facecolor='w', figsize=(10,3))
ax.plot(y_val, marker = 'o', label='y_val')
ax.plot(y_pred, marker = 'x', label='y_pred')
ax.legend()
plt.show()
# Out:
# RMSE :  6.038400867727322

# %% [markdown]
# ### Boruta approach

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn import metrics
from sklearn.metrics import mean_squared_error
import numpy as np
from matplotlib import pyplot as plt

# %%
from boruta import BorutaPy

# %%
boston = datasets.load_boston()
x = boston.data
y = boston.target
x_train, x_val, y_train, y_val = train_test_split(x, y, train_size=0.75)

# %%
model = RandomForestRegressor()
feat_selector = BorutaPy(
    model,
    n_estimators='auto',
    alpha=0.05,
    two_step= True,
    verbose=2,
#     random_state=42,
    perc=80,
    max_iter=150
)
feat_selector.fit(x_train, y_train)

x_train_selected = x_train[:, feat_selector.support_]
x_val_selected = x_val[:, feat_selector.support_]
# Out:
# Iteration: 	1 / 150
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	2 / 150
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	3 / 150
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	4 / 150
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	5 / 150
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	6 / 150
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	7 / 150
# Confirmed: 	0
# Tentative: 	13
# Rejected: 	0
# Iteration: 	8 / 150
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	2
# Iteration: 	9 / 150
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	2
# Iteration: 	10 / 150
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	2
# Iteration: 	11 / 150
# Confirmed: 	9
# Tentative: 	2
# Rejected: 	2
# Iteration: 	12 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	13 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	14 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	15 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	16 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	17 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	18 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	19 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	20 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	21 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	22 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	23 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	24 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	25 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	26 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	27 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	28 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	29 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	30 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	31 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	32 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	33 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	34 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	35 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	36 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	37 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	38 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	39 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	40 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	41 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	42 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	43 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	44 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	45 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	46 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	47 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	48 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	49 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	50 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	51 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	52 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	53 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	54 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	55 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	56 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	57 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	58 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	59 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	60 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	61 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	62 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	63 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	64 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	65 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	66 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	67 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	68 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	69 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	70 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	71 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	72 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	73 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	74 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	75 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	76 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	77 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	78 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	79 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	80 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	81 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	82 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	83 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	84 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	85 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	86 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	87 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	88 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	89 / 150
# Confirmed: 	9
# Tentative: 	1
# Rejected: 	3
# Iteration: 	90 / 150
# Confirmed: 	9
# Tentative: 	0
# Rejected: 	4
#
#
# BorutaPy finished running.
#
# Iteration: 	91 / 150
# Confirmed: 	9
# Tentative: 	0
# Rejected: 	4

# %%
model.fit(x_train_selected, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=44,
#                       n_jobs=None, oob_score=False,
#                       random_state=<mtrand.RandomState object at 0x7f09c0ec8fc0>,
#                       verbose=0, warm_start=False)

# %%
y_pred = model.predict(x_val_selected)
rmse = np.sqrt(mean_squared_error(y_val, y_pred))
print('RMSE : {}'.format(rmse))

fig, ax = plt.subplots(facecolor='w', figsize=(10,3))
ax.plot(y_val, marker = 'o', label='y_val')
ax.plot(y_pred, marker = 'x', label='y_pred')
ax.legend()
plt.show()
# Out:
# RMSE : 3.2166945311365986

# %% [markdown]
# ### Optuna approach

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn import metrics
from sklearn.metrics import mean_squared_error
import numpy as np
from matplotlib import pyplot as plt

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate

# %%
import optuna

# %%
def objective(trial):
#     min_samples_split = trial.suggest_int("min_samples_split", 2, 20)
    n_estimators = trial.suggest_int("n_estimators", 10, 100)
#     criterion = trial.suggest_categorical("criterion", ["gini", "entropy"])
    
    model = RandomForestRegressor(
#         min_samples_split=min_samples_split,
        n_estimators=n_estimators
#         criterion=criterion
    )
    
    kf = KFold(5, shuffle=True, random_state=1).get_n_splits(x_train)
    scores = cross_validate(model, x_train, y_train, cv=kf, verbose=0)
    
    return scores['test_score'].mean()

# %%
study = optuna.create_study()
study.optimize(func=objective,
               n_trials=100, 
               timeout=None, 
               n_jobs=-1
              )
# Out:
# [I 2019-12-04 00:35:22,853] Finished trial#2 resulted in value: 0.791244468979009. Current best value is 0.791244468979009 with parameters: {'n_estimators': 11}.
# [I 2019-12-04 00:35:24,270] Finished trial#1 resulted in value: 0.8050960426990246. Current best value is 0.791244468979009 with parameters: {'n_estimators': 11}.
# [I 2019-12-04 00:35:24,747] Finished trial#4 resulted in value: 0.803064046501343. Current best value is 0.791244468979009 with parameters: {'n_estimators': 11}.
# [I 2019-12-04 00:35:25,373] Finished trial#5 resulted in value: 0.783395870686134. Current best value is 0.783395870686134 with parameters: {'n_estimators': 13}.
# [I 2019-12-04 00:35:25,841] Finished trial#3 resulted in value: 0.7996848415324027. Current best value is 0.783395870686134 with parameters: {'n_estimators': 13}.
# [I 2019-12-04 00:35:26,578] Finished trial#0 resulted in value: 0.802095258824324. Current best value is 0.783395870686134 with parameters: {'n_estimators': 13}.
# [I 2019-12-04 00:35:27,316] Finished trial#7 resulted in value: 0.8042151100496516. Current best value is 0.783395870686134 with parameters: {'n_estimators': 13}.
# [I 2019-12-04 00:35:28,089] Finished trial#6 resulted in value: 0.8004306828894343. Current best value is 0.783395870686134 with parameters: {'n_estimators': 13}.
# [I 2019-12-04 00:35:28,755] Finished trial#10 resulted in value: 0.7996278184573086. Current best value is 0.783395870686134 with parameters: {'n_estimators': 13}.
# [I 2019-12-04 00:35:29,468] Finished trial#11 resulted in value: 0.8070094347548025. Current best value is 0.783395870686134 with parameters: {'n_estimators': 13}.
# [I 2019-12-04 00:35:29,932] Finished trial#8 resulted in value: 0.8041904784541185. Current best value is 0.783395870686134 with parameters: {'n_estimators': 13}.
# [I 2019-12-04 00:35:30,368] Finished trial#9 resulted in value: 0.8034402978112002. Current best value is 0.783395870686134 with parameters: {'n_estimators': 13}.
# [I 2019-12-04 00:35:30,954] Finished trial#12 resulted in value: 0.8034173960224786. Current best value is 0.783395870686134 with parameters: {'n_estimators': 13}.
# [I 2019-12-04 00:35:31,466] Finished trial#13 resulted in value: 0.7672576225116077. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:35:32,022] Finished trial#14 resulted in value: 0.7966451707491651. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:35:32,551] Finished trial#15 resulted in value: 0.7897634419780283. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:35:33,053] Finished trial#16 resulted in value: 0.7843501977542269. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:35
Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:03,072] Finished trial#64 resulted in value: 0.8019243028576588. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:03,638] Finished trial#65 resulted in value: 0.799904245232381. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:04,340] Finished trial#68 resulted in value: 0.7857333226103024. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:04,867] Finished trial#66 resulted in value: 0.8091241068546049. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:05,556] Finished trial#67 resulted in value: 0.8133224615836692. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:06,142] Finished trial#70 resulted in value: 0.7865796382723242. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:06,620] Finished trial#71 resulted in value: 0.8006612465329198. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:07,216] Finished trial#72 resulted in value: 0.7881970550248558. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:07,771] Finished trial#73 resulted in value: 0.7889017937690721. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:08,253] Finished trial#74 resulted in value: 0.786513416427308. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:08,825] Finished trial#75 resulted in value: 0.7799533344481837. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:09,297] Finished trial#69 resulted in value: 0.7943249668155971. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:10,050] Finished trial#77 resulted in value: 0.8073428528107819. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:10,583] Finished trial#78 resulted in value: 0.8074410055839888. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:11,114] Finished trial#79 resulted in value: 0.798150186190956. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:11,850] Finished trial#81 resulted in value: 0.8003003064220184. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:12,653] Finished trial#76 resulted in value: 0.800480405382846. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:13,339] Finished trial#84 resulted in value: 0.8060114539511231. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:13,987] Finished trial#85 resulted in value: 0.7915274673807189. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:14,547] Finished trial#80 resulted in value: 0.8006407306238958. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:15,035] Finished trial#82 resulted in value: 0.7990495599370115. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:15,596] Finished trial#86 resulted in value: 0.782780771895163. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:16,145] Finished trial#87 resulted in value: 0.7978841331111154. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:16,603] Finished trial#83 resulted in value: 0.8006779972751431. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:17,068] Finished trial#88 resulted in value: 0.7982814084964123. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:17,616] Finished trial#89 resulted in value: 0.7879255725019301. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:18,202] Finished trial#90 resulted in value: 0.7994760572458675. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:18,658] Finished trial#91 resulted in value: 0.7961698035651474. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:19,149] Finished trial#92 resulted in value: 0.8022697351224919. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:19,741] Finished trial#94 resulted in value: 0.8068610389365825. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:20,208] Finished trial#95 resulted in value: 0.7776784289722443. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:20,694] Finished trial#96 resulted in value: 0.8064833597863901. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:21,164] Finished trial#93 resulted in value: 0.7973581178918681. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:21,669] Finished trial#98 resulted in value: 0.7942649801051399. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:22,089] Finished trial#97 resulted in value: 0.7970133274185413. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.
# [I 2019-12-04 00:36:22,527] Finished trial#99 resulted in value: 0.7906207372671566. Current best value is 0.7672576225116077 with parameters: {'n_estimators': 10}.

# %%
model_tuned = RandomForestRegressor(min_samples_split=2,
                                                                           n_estimators=10)
model_tuned.fit(x_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
y_pred = model_tuned.predict(x_val)
rmse = np.sqrt(mean_squared_error(y_val, y_pred))
print('RMSE : {}'.format(rmse))

fig, ax = plt.subplots(facecolor='w', figsize=(10,3))
ax.plot(y_val, marker = 'o', label='y_val')
ax.plot(y_pred, marker = 'x', label='y_pred')
ax.legend()
plt.show()
# Out:
# RMSE : 2.9326877570438628

# %% [markdown]
# # References

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# https://funatsu-lab.github.io/open-course-ware/machine-learning/random-forest/
